# %%
from src.data.make_dataset import *
from src.config import *

# %% [markdown]
# ## Split data into train, test, (validation)

# %%
train, test = split_train_test(path_img, path_mask, 0.2, True)

# %% [markdown]
# #### Look at train- and test data

# %%
print('Number of data: ' + str(len(train)))
train.head()
# Out:
# Number of data: 2075
#               Image                           Mask  is_validation
# 0  ISIC_0000031.jpg  ISIC_0000031_segmentation.png           True
# 1  ISIC_0010204.jpg  ISIC_0010204_segmentation.png           True
# 2  ISIC_0013089.jpg  ISIC_0013089_segmentation.png           True
# 3  ISIC_0014522.jpg  ISIC_0014522_segmentation.png          False
# 4  ISIC_0013767.jpg  ISIC_0013767_segmentation.png          False

# %%
print('Number of data: ' + str(len(test)))
test.head()
# Out:
# Number of data: 519
#               Image                           Mask
# 0  ISIC_0012311.jpg  ISIC_0012311_segmentation.png
# 1  ISIC_0013163.jpg  ISIC_0013163_segmentation.png
# 2  ISIC_0011173.jpg  ISIC_0011173_segmentation.png
# 3  ISIC_0010852.jpg  ISIC_0010852_segmentation.png
# 4  ISIC_0000330.jpg  ISIC_0000330_segmentation.png

# %% [markdown]
# #### Save to .csv

# %%
train.to_csv(path_trainingset, index=False)
test.to_csv(path_testset, index=False)

# %% [markdown]
# #### Show batch

# %% [markdown]
# Trainingset

# %%
show_batch(train, path_img, path_mask)

# %% [markdown]
# Testset

# %%
show_batch(test, path_img, path_mask)
