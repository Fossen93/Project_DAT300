# %%
from src.data.make_dataset import *
from src.config import *

# %% [markdown]
# ## Split data into train, test, (validation)

# %%
train, test = split_train_test(path_img, path_mask, 0.2, True)

# %% [markdown]
# #### Look at train- and test data

# %%
print('Number of data: ' + str(len(train)))
train.head()
# Out:
# Number of data: 2075
#               Image                           Mask  is_validation
# 0  ISIC_0013678.jpg  ISIC_0013678_segmentation.png           True
# 1  ISIC_0014610.jpg  ISIC_0014610_segmentation.png           True
# 2  ISIC_0011149.jpg  ISIC_0011149_segmentation.png           True
# 3  ISIC_0000493.jpg  ISIC_0000493_segmentation.png          False
# 4  ISIC_0001449.jpg  ISIC_0001449_segmentation.png          False

# %%
print('Number of data: ' + str(len(test)))
test.head()
# Out:
# Number of data: 519
#               Image                           Mask
# 0  ISIC_0013492.jpg  ISIC_0013492_segmentation.png
# 1  ISIC_0010379.jpg  ISIC_0010379_segmentation.png
# 2  ISIC_0013680.jpg  ISIC_0013680_segmentation.png
# 3  ISIC_0013141.jpg  ISIC_0013141_segmentation.png
# 4  ISIC_0011120.jpg  ISIC_0011120_segmentation.png

# %% [markdown]
# #### Save to .csv

# %%
train.to_csv(path_trainingset, index=False)
test.to_csv(path_testset, index=False)

# %% [markdown]
# #### Show batch

# %% [markdown]
# Trainingset

# %%
show_batch(train, path_img, path_mask)

# %% [markdown]
# Testset

# %%
show_batch(test, path_img, path_mask)
